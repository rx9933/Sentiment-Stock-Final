# %% [markdown]
# pinn + 8 features
#
# 1. close
# 2. volume
# 3. sma_30
# 4. sma_100
# 5. volatility
# 6. option_price
# 7. 2 henkel - dmd modes  (7,8)

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, LeakyReLU
from tensorflow.keras.optimizers import Adam
from scipy.stats import norm
from scipy.linalg import svd
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import os 

# Fetch stock data from Yahoo Finance
def fetch_stock_data(ticker, start_date, end_date):
    data = yf.download(ticker, start=start_date, end=end_date)
    return data

# Compute technical indicators
def compute_technical_indicators(data):
    data['SMA30'] = data['Close'].rolling(window=30).mean()
    data['SMA100'] = data['Close'].rolling(window=100).mean()
    vol_window = 21
    data['Volatility'] = data['Close'].pct_change().rolling(window=vol_window).std() * np.sqrt(252)
    return data.dropna()

# Black-Scholes option pricing model
def black_scholes(S, K, T, r, sigma, option_type='call'):
    d1 = (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    if option_type == 'call':
        return S * norm.cdf(d1) - K * np.exp(-r * T) * norm.cdf(d2)
    elif option_type == 'put':
        return K * np.exp(-r * T) * norm.cdf(-d2) - S * norm.cdf(-d1)

# Apply Black-Scholes model to generate option prices
def add_option_pricing_features(data):
    strike_price = data['Close'] * 1.05
    time_to_maturity = 30 / 252
    risk_free_rate = 0.01
    option_type = 'call'
    data['Option_Price'] = black_scholes(data['Close'], strike_price, time_to_maturity, risk_free_rate, data['Volatility'], option_type)
    data['Implied_Volatility'] = data['Volatility']
    return data

# Normalize and apply PCA for dimensionality reduction
def preprocess_data(data, n_pca_components=2):
    scaler = MinMaxScaler()
    data_scaled = scaler.fit_transform(data)
    # pca = PCA(n_components=n_pca_components)
    # data_pca = pca.fit_transform(data_scaled)
    # return np.hstack((data_scaled, data_pca))
    return data_scaled, scaler

# Create sequences for time-series prediction
def create_sequences(data, seq_len, pred_len):
    sequences = []
    for i in range(len(data) - seq_len - pred_len + 1):
        sequences.append(data[i:i + seq_len + pred_len])
    return np.array(sequences)

# Function to create a Hankel matrix
def create_hankel_matrix(time_series, window_size):
    # Create a Hankel matrix where the columns are shifted versions of the time series
    hankel_matrix = np.array([time_series[i:i + window_size] for i in range(len(time_series) - window_size + 1)])
    return hankel_matrix

# Function to perform SVD on the Hankel matrix
def hankel_svd(hankel_matrix):
    # Perform SVD on the Hankel matrix
    U, Sigma, Vt = svd(hankel_matrix, full_matrices=False)
    return U, Sigma, Vt

# Build a neural network model
def build_model(input_shape, output_len):
    model = Sequential([
        Flatten(input_shape=input_shape),
        Dense(180),
        LeakyReLU(),
        Dense(360),
        LeakyReLU(),
        Dense(360),
        LeakyReLU(),
        Dense(output_len)
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    return model



def predict_and_plot(m, ticker, data, s, model, seq_len, pred_len, scaler, cut_off):
    plt.figure(figsize=(14, 7))

    rmse_values = []  # To store RMSE values for each section
    section_start_idx = []  # To store the start indices of each 30-day section for placement of RMSE labels
    #s.shape[0]
    for idx in range(0,cut_off+pred_len , pred_len):  # Loop through each 30-day block
    # for idx in range(1): # only first 30 after being trained
        # Input remains in 3D for predictio
        future_input = s[idx, :seq_len, :].reshape(1, seq_len, -1)  # Keep the 3D shape
        future = model.predict(future_input)[0]  # Predict future "Close" prices
        # Pad the prediction with zeros for the "Volume" and "SMA" columns
        future_padded = np.hstack((future.reshape(-1, 1), np.zeros((future.shape[0], data.shape[1] - 3))))  # Adjust for PCA features

        # Inverse transform the padded prediction
        future_transform = scaler.inverse_transform(future_padded)[:, 0]  # Extract "Close"

        # Extract and inverse transform the true "Close" values
        future_true = s[idx, seq_len:, 0].reshape(-1, 1)  # Use only "Close"
        future_true_padded = np.hstack((future_true, np.zeros((future_true.shape[0], data.shape[1] - 3))))  # Adjust for PCA features
        future_true_transform = scaler.inverse_transform(future_true_padded)[:, 0]  # Extract "Close"

        # Calculate RMSE for this 30-day section
        rmse = np.sqrt(mean_squared_error(future_true_transform, future_transform))
        rmse_values.append(rmse)
        section_start_idx.append(idx)  # Store the start index for the RMSE label

        # Plot the predictions
        plt.plot(np.arange(idx, idx + pred_len), future_transform, 
                # label="Train Prediction" if idx < cut_off else "Test Prediction", 
                 color="red" if idx < cut_off else "blue")

        # Plot the true values
        plt.plot(np.arange(idx, idx + pred_len), future_true_transform, 
                 #label="Train True" if idx < cut_off else "Test True", 
                 color="black" if idx < cut_off else "green")

        
    
    # Add legend and grid
    # plt.legend(["Train Prediction", "Train True", "Test Prediction", "Test True"])
    plt.plot([], [], color="red", label="Train Prediction")  # Dummy plot for legend
    plt.plot([], [], color="black", label="Train True")      # Dummy plot for legend
    plt.plot([], [], color="blue", label="Test Prediction")  # Dummy plot for legend
    plt.plot([], [], color="green", label="Test True")      # Dummy plot for legend
    plt.legend()
    for idx in range(0, s.shape[0], pred_len): 
    # Add vertical line to separate each 30-day section
        plt.axvline(x=idx + pred_len, color='gray', linestyle='--', linewidth=1)
    # Title and labels
    
    plt.title(f"{seq_len}-{pred_len} Predictions for {ticker}, model {m}")
    plt.xlabel("Trading Days")
    plt.ylabel("Price")

    # Add RMSE labels below the x-axis at the start of each 30-day section
    for i, rmse in zip(section_start_idx, rmse_values):
        plt.text(i + pred_len / 2, min(plt.ylim()), f"{rmse:.0f}", color="teal", fontsize=10, ha='center', va='top')
    plt.text(- 5- pred_len / 2, min(plt.ylim()), f"RMSE", color="teal", fontsize=10, ha='center', va='top')
    print(rmse_values)
    plt.grid(True)
    if m == "PINN w/ 8 features":
        dir = f"data/{seq_len}-{pred_len}/pinn_8"
        if not os.path.exists(dir):
                os.makedirs(dir)
        plt.savefig(f"{dir}/{ticker}.png")
    return rmse_values[-1] # testing rmse

    # plt.show()

# Call the function


# Main workflow
def main(tickers):
    m = "PINN w/ 8 features"
    test_rmse = []
    for ticker in tickers:
        # Step 1: Fetch data
        tsla = fetch_stock_data(ticker, start_date="2021-01-01", end_date="2024-09-30")

        # Step 2: Compute indicators
        tsla = compute_technical_indicators(tsla)

        # Step 3: Add Black-Scholes option pricing
        tsla = add_option_pricing_features(tsla)

        # Step 4: Prepare data for training
        features = ['Close', 'Volume', 'SMA30', 'SMA100', 'Volatility', 'Implied_Volatility']
        data = tsla[features].copy()
        # Step 5: Perform Hankel Matrix Decomposition
        window_size = 50  # Size of the sliding window to form the Hankel matrix
        hankel_matrix = create_hankel_matrix(data['Close'].values, window_size)

        # Step 6: Perform SVD on the Hankel matrix
        U, Sigma, Vt = hankel_svd(hankel_matrix)

        # You can choose the first few singular values and modes to add as features
        num_modes = 2  # Number of modes to add as features
        dmd_modes = U[:, :num_modes]  # Select the modes
        dmd_amplitudes = Sigma[:num_modes]  # Select the amplitudes

        # Step 7: Normalize and apply PCA for dimensionality reduction
        processed_data,scaler = preprocess_data(data)

        # Trim the processed_data to match the number of rows in dmd_modes
        processed_data_trimmed = processed_data[-dmd_modes.shape[0]:]  # Trim to match the length of dmd_modes

        # Combine the Hankel decomposition modes with the processed data
        data_combined = np.hstack((processed_data_trimmed, dmd_modes))

        # Step 8: Create sequences for time-series prediction
        seq_len = 6 * 30  # 6 months of data
        pred_len = 20  # Predict the next 20 days
        sequences = create_sequences(data_combined, seq_len, pred_len)

        # Step 9: Split data into training and testing
        cut_off = int(0.95 * sequences.shape[0])
        X_train = sequences[:cut_off, :seq_len, :]
        X_test = sequences[cut_off:, :seq_len, :]
        y_train = sequences[:cut_off, seq_len:, 0]
        y_test = sequences[cut_off:, seq_len:, 0]
        print(sequences.shape)
        
        # Step 10: Build and train the model
        model = build_model(input_shape=(seq_len, X_train.shape[2]), output_len=pred_len)
        history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=32,
            verbose=1
        )

        test_rmse += [predict_and_plot(m, ticker, data_combined, sequences, model, seq_len, pred_len, scaler, cut_off)]

    mse_for_model  = np.mean(test_rmse)
    return mse_for_model

# %%
tickers = ["TSLA","NVDA","AMZN","MSFT", "BIPC", "JNJ","WMB","HMC","MSFT", "TM"]
mse = main(tickers)
# Out:
# [*********************100%***********************]  1 of 1 completed
# (593, 200, 8)
# Epoch 1/100
# /tmp/ipykernel_29364/3468498574.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Option_Price'] = black_scholes(data['Close'], strike_price, time_to_maturity, risk_free_rate, data['Volatility'], option_type)
# /tmp/ipykernel_29364/3468498574.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Implied_Volatility'] = data['Volatility']
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0848
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0118
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0059
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0040
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0018
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0013
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9675e-04
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9580e-04
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4078e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7442e-04
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7811e-04
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8494e-04
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6911e-04
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4933e-04
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7950e-04
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9508e-04
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2121e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5604e-04
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0489e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4278e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7330e-04
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1894e-04
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1013e-04
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7265e-04
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2280e-04
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5030e-04
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0401e-04
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7254e-04
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.9644e-04
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1540e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.7259e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0090e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3063e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8000e-04
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3892e-04
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.2060e-04
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2236e-04
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9111e-04
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6488e-04
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8900e-04
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4096e-04
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8243e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4639e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7284e-04
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4693e-04
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3763e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.8825e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2149e-04
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7864e-04
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6198e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1194e-04
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5920e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7237e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4693e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5895e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2065e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6110e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3227e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1015e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7050e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8869e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3557e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4330e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2378e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1838e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8436e-04
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6792e-04
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3955e-04
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5421e-04
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7195e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [7.527116703203074, 10.567118160855255, 8.256112879038838, 9.632277142182875, 9.45188910477955, 8.476526239151958, 9.437562969552385, 7.091599579694075, 5.732293515284198, 5.388243836281235, 5.574026687585086, 7.489094008979146, 4.81151590761449, 7.283915366986426, 6.662603866388369, 7.665705620427627, 5.649471664229065, 5.5845449928988655, 5.484906759621913, 6.305614035989973, 6.554794227711282, 4.493062496396813, 7.343565885375414, 5.608909122326616, 5.217622732901049, 7.382466996051443, 4.247811066975333, 7.074376652220633, 6.882790344601754, 29.913034159364038]
# [*********************100%***********************]  1 of 1 completed
# (593, 200, 8)
# Epoch 1/100
# /tmp/ipykernel_29364/3468498574.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Option_Price'] = black_scholes(data['Close'], strike_price, time_to_maturity, risk_free_rate, data['Volatility'], option_type)
# /tmp/ipykernel_29364/3468498574.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Implied_Volatility'] = data['Volatility']
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0451
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5887e-04
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4502e-04
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3069e-04
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6370e-04
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3089e-04
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4556e-04
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0197e-04
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2352e-04
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4979e-04
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7418e-04
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9409e-04
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7042e-04
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4274e-04
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7419e-04
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1696e-04
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4663e-04
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1101e-04
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9387e-04
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6686e-04
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1452e-04
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6973e-04
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7338e-04
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0241e-04
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3795e-04
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8139e-04
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4822e-04
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2989e-04
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3666e-04
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4234e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3327e-04
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4042e-04
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4349e-04
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1765e-04
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2661e-04
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1643e-04
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1606e-04
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1560e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5919e-04
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4572e-04
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3835e-04
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4839e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1744e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5315e-04
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9725e-04
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0498e-04
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5865e-04
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2293e-04
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5178e-04
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7609e-04
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4544e-04
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5375e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8706e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5850e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3167e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1776e-04
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0823e-04
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2556e-04
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6277e-04
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7049e-04
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7920e-04
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0718e-04
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7221e-04
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7609e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8905e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9953e-04
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6648e-04
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6289e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3961e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4442e-04
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4140e-04
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5510e-04
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5236e-04
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6202e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6389e-04
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5310e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5754e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4403e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0720e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6840e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2231e-04
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1339e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8054e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7527e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9386e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5537e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3973e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2812e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8589e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7594e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5801e-04
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8749e-04
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6181e-04
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5458e-04
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7769e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [0.6616005918600413, 0.8812736589728319, 0.5500581898675314, 0.575058274622352, 0.7614147098277666, 0.5549197768505287, 0.602873780477224, 0.6836632525642589, 0.6093255279256463, 0.7048862813295484, 0.9795262318612958, 0.7362433414834444, 0.7444813925628219, 1.2305991838870411, 0.625183055748263, 0.7228037557560674, 1.0958797725110019, 0.7515696111630799, 1.0184189420775953, 0.8418512564587934, 1.0543847231906638, 1.2875039388375087, 2.207374576682644, 2.4178893276801556, 1.8903919683936254, 2.07577801613054, 3.51623331270613, 3.374040265064332, 4.0539495289261245, 16.234461476626382]
# [*********************100%***********************]  1 of 1 completed
# (593, 200, 8)
# Epoch 1/100
# /tmp/ipykernel_29364/3468498574.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Option_Price'] = black_scholes(data['Close'], strike_price, time_to_maturity, risk_free_rate, data['Volatility'], option_type)
# /tmp/ipykernel_29364/3468498574.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Implied_Volatility'] = data['Volatility']
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1159
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0165
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0069
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0022
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0013
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0019
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3947e-04
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6437e-04
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.8733e-04
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0400e-04
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.5620e-04
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4846e-04
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1659e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7176e-04
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1118e-04
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1714e-04
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2200e-04
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2656e-04
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 7.1729e-04
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7136e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8569e-04
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9664e-04
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3756e-04
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0584e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 8.3174e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.9855e-04
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0010
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9390e-04
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.9322e-04
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5377e-04
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9236e-04
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.2228e-04
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0353e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4493e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9254e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.6760e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5037e-04
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.3134e-04
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.3169e-04
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.0252e-04
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5038e-04
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0259e-04
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0011
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7975e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.8105e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2516e-04
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9296e-04
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7105e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.0577e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.0496e-04
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5630e-04
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4879e-04
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7134e-04
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7627e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1278e-04
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.7457e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6776e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.9264e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7099e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4238e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5694e-04
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8497e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0477e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6876e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0681e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1919e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5222e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0864e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1798e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9173e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1346e-04
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9151e-04
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3084e-04
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4341e-04
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5474e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [2.7169053746751817, 1.824146436015872, 2.305678597292277, 2.257876179328697, 2.555128944494873, 2.231495661013986, 2.0112396344252725, 1.81756226461064, 1.153894739484268, 1.9220411441125653, 1.4083244248186844, 1.368549344714241, 1.3877143639288643, 1.4162423508361828, 1.4707887799690704, 1.2136110308070902, 2.247878361037522, 2.1486531595379352, 2.0299927137079448, 2.619003482298216, 1.4238895610124074, 2.4972679340071666, 3.2243448756474002, 2.583844477990131, 2.1310046346373, 3.051580549706853, 2.800250091825199, 4.362866598367209, 3.511601405189213, 18.253003915379548]
# [*********************100%***********************]  1 of 1 completed
# (593, 200, 8)
# Epoch 1/100
# /tmp/ipykernel_29364/3468498574.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Option_Price'] = black_scholes(data['Close'], strike_price, time_to_maturity, risk_free_rate, data['Volatility'], option_type)
# /tmp/ipykernel_29364/3468498574.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Implied_Volatility'] = data['Volatility']
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0934
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0104
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0048
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8691e-04
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6529e-04
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3434e-04
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8066e-04
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8747e-04
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6003e-04
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3991e-04
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6796e-04
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7307e-04
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8475e-04
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2355e-04
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3361e-04
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6395e-04
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6360e-04
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7228e-04
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3133e-04
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0316e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0658e-04
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9236e-04
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1161e-04
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7384e-04
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0873e-04
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8061e-04
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1613e-04
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2959e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1851e-04
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.0281e-04
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9235e-04
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5046e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1590e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0751e-04
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4063e-04
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6201e-04
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1458e-04
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7946e-04
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5254e-04
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3327e-04
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8835e-04
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8159e-04
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4370e-04
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1054e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3518e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0976e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3538e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3044e-04
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0726e-04
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2193e-04
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4221e-04
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0250e-04
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8574e-04
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2216e-04
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5815e-04
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0281e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6194e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3708e-04
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3376e-04
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8323e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3313e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6479e-04
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9458e-04
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.5110e-04
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2357e-04
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7588e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8950e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.5989e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6356e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1151e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3849e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7523e-04
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8515e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2962e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0543e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7250e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7717e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3759e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5007e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5102e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8021e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8788e-04
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9588e-04
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5621e-04
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4881e-04
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8451e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [3.7492278411064754, 3.7248414294479275, 3.375191983783215, 3.9643173918301136, 3.803655829805451, 3.4610715267851595, 4.4807796879909265, 2.68571081889295, 2.7603847914695594, 3.6416311565823083, 2.8352291883966694, 3.444350658787518, 3.2317681223566423, 3.2745508671568584, 3.968386740685867, 4.285370223155527, 2.515999172005402, 3.6645708241228365, 3.030671315933711, 4.0357371238561175, 3.678741446608797, 3.361394305737432, 6.09212004419193, 4.864695290163169, 4.56871920906015, 6.04164464458403, 4.923799524829835, 6.045211291810004, 5.5909212907637995, 42.331638488296065]
# [*********************100%***********************]  1 of 1 completed
# (593, 200, 8)
# Epoch 1/100
# /tmp/ipykernel_29364/3468498574.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Option_Price'] = black_scholes(data['Close'], strike_price, time_to_maturity, risk_free_rate, data['Volatility'], option_type)
# /tmp/ipykernel_29364/3468498574.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Implied_Volatility'] = data['Volatility']
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1250
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0182
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0141
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0092
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0060
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0050
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0048
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0038
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0027
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0018
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7809e-04
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6207e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.0227e-04
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9433e-04
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6780e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6554e-04
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8098e-04
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9361e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0768e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0422e-04
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4688e-04
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1939e-04
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7022e-04
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8316e-04
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4771e-04
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4571e-04
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8991e-04
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8567e-04
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8383e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3404e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8822e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2736e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1492e-04
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8336e-04
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.1712e-04
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.4662e-04
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9703e-04
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9036e-04
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2477e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8138e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6100e-04
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3590e-04
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5981e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5231e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0059
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3550e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5846e-04
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7670e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0740e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1188e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6267e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4119e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3564e-04
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.8351e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6907e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9996e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1167e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4823e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4629e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8422e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0529e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9494e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4866e-04
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5025e-04
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4161e-04
# Epoch 99/100
# ...
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9920e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5186e-04
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.0749e-04
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0507e-04
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.8593e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9240e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9595e-04
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9739e-04
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6074e-04
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9698e-04
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9052e-04
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4658e-04
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7572e-04
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5737e-04
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9198e-04
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.8187e-04
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4719e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1846e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7433e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4952e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4261e-04
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3515e-04
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7881e-04
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.4429e-04
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.8245e-04
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.6055e-04
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1907e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6380e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7360e-04
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6219e-04
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7129e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0195e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3225e-04
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3053e-04
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0549e-04
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.5881e-04
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7909e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1421e-04
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9500e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8427e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6754e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8787e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.9106e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6048e-04
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3692e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4794e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6873e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7805e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8040e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7527e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1451e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4850e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6864e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4798e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [6.930282714945761, 6.5715722421856535, 5.653131571116448, 7.521954844080898, 8.188992532214593, 5.661819112639841, 5.706693011662412, 5.636026852557286, 6.031113433265571, 5.514652126237879, 5.411648312955107, 4.280332571346836, 6.2826215900231315, 4.8002924257000705, 7.703897688538108, 6.907683227682151, 5.0160528368675426, 6.649377623885753, 6.061379968450015, 5.65875278586249, 7.259539375472311, 7.481435470835388, 6.943278896542744, 7.089423247922377, 10.227569806223222, 6.865597500157213, 7.100483261933335, 11.169773687017676, 4.823836151980112, 39.45895792326681]
# [*********************100%***********************]  1 of 1 completed
# (593, 200, 8)
# Epoch 1/100
# /tmp/ipykernel_29364/3468498574.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Option_Price'] = black_scholes(data['Close'], strike_price, time_to_maturity, risk_free_rate, data['Volatility'], option_type)
# /tmp/ipykernel_29364/3468498574.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Implied_Volatility'] = data['Volatility']
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0702
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0095
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5827e-04
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5020e-04
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1392e-04
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1177e-04
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4187e-04
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7117e-04
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0031e-04
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9939e-04
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8405e-04
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6192e-04
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5944e-04
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1741e-04
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6420e-04
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8339e-04
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4640e-04
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9919e-04
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5492e-04
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.8343e-04
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6870e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6878e-04
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8311e-04
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5035e-04
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2380e-04
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7182e-04
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7589e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3981e-04
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0375e-04
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6674e-04
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4195e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7414e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5423e-04
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4260e-04
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8891e-04
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8776e-04
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3774e-04
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0650e-04
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7484e-04
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9911e-04
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3543e-04
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1578e-04
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4105e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3472e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8377e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5990e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0461e-04
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0482e-04
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7354e-04
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5551e-04
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9644e-04
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.9127e-04
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0130e-04
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6194e-04
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7541e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2585e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0673e-04
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4554e-04
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4297e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7772e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2766e-04
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4190e-04
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8812e-04
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5483e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4964e-04
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1600e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3948e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9658e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0748e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4882e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6931e-04
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1798e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0901e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1971e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7698e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0987e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3254e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4336e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8620e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3676e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6072e-04
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3425e-04
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0079
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [7.2414496952280345, 5.168130372423632, 2.8863038199211823, 4.655708568305274, 4.094214951900334, 3.3698154004835716, 3.2758560030714947, 2.8784467131549025, 3.642691276179111, 2.329561801983513, 3.275079506524683, 2.1891490403593967, 2.494352195325211, 3.846348110710115, 4.1732564388885836, 2.4307499980845924, 3.8255474238563836, 2.79786691219453, 2.1925430185744865, 4.4480156951482765, 3.4852360403685236, 2.5527298413133805, 4.12962512518428, 6.803481263239114, 10.082438768461053, 5.258373718887704, 6.079087111269384, 5.140165127960241, 6.712234674338013, 5.356750873373269]

# %%
mse
# Out:
# 16.515473197572785
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
