# %%
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, LeakyReLU
from tensorflow.keras.optimizers import Adam
from scipy.stats import norm
from scipy.linalg import svd
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import os 

# Fetch stock data from Yahoo Finance
def fetch_stock_data(ticker, start_date, end_date):
    data = yf.download(ticker, start=start_date, end=end_date)
    return data

# Compute technical indicators
def compute_technical_indicators(data):
    data['SMA30'] = data['Close'].rolling(window=30).mean()
    data['SMA100'] = data['Close'].rolling(window=100).mean()
    vol_window = 30
    data['Volatility'] = data['Close'].pct_change().rolling(window=vol_window).std() * np.sqrt(252)
    return data.dropna()

# Black-Scholes option pricing model
def black_scholes(S, K, T, r, sigma, option_type='call'):
    d1 = (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    if option_type == 'call':
        return S * norm.cdf(d1) - K * np.exp(-r * T) * norm.cdf(d2)
    elif option_type == 'put':
        return K * np.exp(-r * T) * norm.cdf(-d2) - S * norm.cdf(-d1)

# Apply Black-Scholes model to generate option prices
def add_option_pricing_features(data):
    strike_price = data['Close'] * 1.05
    time_to_maturity = 30 / 252
    risk_free_rate = 0.01
    option_type = 'call'
    data['Option_Price'] = black_scholes(data['Close'], strike_price, time_to_maturity, risk_free_rate, data['Volatility'], option_type)
    data['Implied_Volatility'] = data['Volatility']
    return data

# Normalize and apply PCA for dimensionality reduction
def preprocess_data(data, n_pca_components=2):
    scaler = MinMaxScaler()
    data_scaled = scaler.fit_transform(data)
    # pca = PCA(n_components=n_pca_components)
    # data_pca = pca.fit_transform(data_scaled)
    # return np.hstack((data_scaled, data_pca))
    return data_scaled, scaler

# Create sequences for time-series prediction
def create_sequences(data, seq_len, pred_len):
    sequences = []
    for i in range(len(data) - seq_len - pred_len + 1):
        sequences.append(data[i:i + seq_len + pred_len])
    return np.array(sequences)

# Function to create a Hankel matrix
def create_hankel_matrix(time_series, window_size):
    # Create a Hankel matrix where the columns are shifted versions of the time series
    hankel_matrix = np.array([time_series[i:i + window_size] for i in range(len(time_series) - window_size + 1)])
    return hankel_matrix

# Function to perform SVD on the Hankel matrix
def hankel_svd(hankel_matrix):
    # Perform SVD on the Hankel matrix
    U, Sigma, Vt = svd(hankel_matrix, full_matrices=False)
    return U, Sigma, Vt

# Build a neural network model
def build_model(input_shape, output_len):
    model = Sequential([
        Flatten(input_shape=input_shape),
        Dense(180),
        LeakyReLU(),
        Dense(360),
        LeakyReLU(),
        Dense(360),
        LeakyReLU(),
        Dense(output_len)
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    return model



def predict_and_plot(m, ticker, data, s, model, seq_len, pred_len, scaler, cut_off):
    plt.figure(figsize=(14, 7))

    rmse_values = []  # To store RMSE values for each section
    section_start_idx = []  # To store the start indices of each 30-day section for placement of RMSE labels
    #s.shape[0]
    for idx in range(0,cut_off+pred_len , pred_len):  # Loop through each 30-day block
    # for idx in range(1): # only first 30 after being trained
        # Input remains in 3D for predictio
        future_input = s[idx, :seq_len, :].reshape(1, seq_len, -1)  # Keep the 3D shape
        future = model.predict(future_input)[0]  # Predict future "Close" prices
        # Pad the prediction with zeros for the "Volume" and "SMA" columns
        future_padded = np.hstack((future.reshape(-1, 1), np.zeros((future.shape[0], data.shape[1] - 3))))  # Adjust for PCA features

        # Inverse transform the padded prediction
        future_transform = scaler.inverse_transform(future_padded)[:, 0]  # Extract "Close"

        # Extract and inverse transform the true "Close" values
        future_true = s[idx, seq_len:, 0].reshape(-1, 1)  # Use only "Close"
        future_true_padded = np.hstack((future_true, np.zeros((future_true.shape[0], data.shape[1] - 3))))  # Adjust for PCA features
        future_true_transform = scaler.inverse_transform(future_true_padded)[:, 0]  # Extract "Close"

        # Calculate RMSE for this 30-day section
        percent_error = np.mean(np.abs((future_true_transform - future_transform) / future_true_transform)) * 100
        rmse_values.append(percent_error)
        section_start_idx.append(idx)  # Store the start index for the percentage error label


        # Plot the predictions
        plt.plot(np.arange(idx, idx + pred_len), future_transform, 
                # label="Train Prediction" if idx < cut_off else "Test Prediction", 
                 color="red" if idx < cut_off else "blue")

        # Plot the true values
        plt.plot(np.arange(idx, idx + pred_len), future_true_transform, 
                 #label="Train True" if idx < cut_off else "Test True", 
                 color="black" if idx < cut_off else "green")

        
    
    # Add legend and grid
    # plt.legend(["Train Prediction", "Train True", "Test Prediction", "Test True"])
    plt.plot([], [], color="red", label="Train Prediction")  # Dummy plot for legend
    plt.plot([], [], color="black", label="Train True")      # Dummy plot for legend
    plt.plot([], [], color="blue", label="Test Prediction")  # Dummy plot for legend
    plt.plot([], [], color="green", label="Test True")      # Dummy plot for legend
    plt.legend()
    for idx in range(0, s.shape[0], pred_len): 
    # Add vertical line to separate each 30-day section
        plt.axvline(x=idx + pred_len, color='gray', linestyle='--', linewidth=1)
    # Title and labels
    
    plt.title(f"{seq_len}-{pred_len} Predictions for {ticker}, model {m}")
    plt.xlabel("Trading Days")
    plt.ylabel("Price")

    # Add RMSE labels below the x-axis at the start of each 30-day section
    for i, rmse in zip(section_start_idx, rmse_values):
        plt.text(i + pred_len / 2, min(plt.ylim()), f"{rmse:.0f}", color="teal", fontsize=10, ha='center', va='top')
    plt.text(- 5- pred_len / 2, min(plt.ylim()), f"MAPE:", color="teal", fontsize=10, ha='center', va='top')
    print(rmse_values)
    plt.grid(True)
    if m == "NN w/ 7 features":
        dir = f"{seq_len}-{pred_len}/nn_7"
        if not os.path.exists(dir):
                os.makedirs(dir)
        plt.savefig(f"{dir}/{ticker}.png")
    return rmse_values[-1] # testing rmse

    # plt.show()

# Call the function


# Main workflow
def main(tickers):
    m = "NN w/ 7 features"
    test_rmse = []
    for ticker in tickers:
        # Step 1: Fetch data
        tsla = fetch_stock_data(ticker, start_date="2021-01-01", end_date="2024-09-30")

        # Step 2: Compute indicators
        tsla = compute_technical_indicators(tsla)

        # Step 3: Add Black-Scholes option pricing
        # tsla = add_option_pricing_features(tsla)

        # Step 4: Prepare data for training
        features = ['Close', 'Volume', 'SMA30', 'SMA100', 'Volatility']
        data = tsla[features].copy()
        # Step 5: Perform Hankel Matrix Decomposition
        window_size = 20  # Size of the sliding window to form the Hankel matrix
        hankel_matrix = create_hankel_matrix(data['Close'].values, window_size)

        # Step 6: Perform SVD on the Hankel matrix
        U, Sigma, Vt = hankel_svd(hankel_matrix)

        # You can choose the first few singular values and modes to add as features
        num_modes = 2  # Number of modes to add as features
        dmd_modes = U[:, :num_modes]  # Select the modes
        dmd_amplitudes = Sigma[:num_modes]  # Select the amplitudes

        # Step 7: Normalize and apply PCA for dimensionality reduction
        processed_data,scaler = preprocess_data(data)

        # Trim the processed_data to match the number of rows in dmd_modes
        processed_data_trimmed = processed_data[-dmd_modes.shape[0]:]  # Trim to match the length of dmd_modes

        # Combine the Hankel decomposition modes with the processed data
        data_combined = np.hstack((processed_data_trimmed, dmd_modes))

        # Step 8: Create sequences for time-series prediction
        seq_len = 6 * 30  # 6 months of data
        pred_len = 20  # Predict the next 20 days
        sequences = create_sequences(data_combined, seq_len, pred_len)

        # Step 9: Split data into training and testing
        cut_off = int(0.95 * sequences.shape[0])
        X_train = sequences[:cut_off, :seq_len, :]
        X_test = sequences[cut_off:, :seq_len, :]
        y_train = sequences[:cut_off, seq_len:, 0]
        y_test = sequences[cut_off:, seq_len:, 0]
        print(sequences.shape)
        
        # Step 10: Build and train the model
        model = build_model(input_shape=(seq_len, X_train.shape[2]), output_len=pred_len)
        history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=32,
            verbose=1
        )

        test_rmse += [predict_and_plot(m, ticker, data_combined, sequences, model, seq_len, pred_len, scaler, cut_off)]

    mse_for_model  = np.mean(test_rmse)
    return mse_for_model

# %%
tickers = ["TSLA","NVDA","AMZN","MSFT", "BIPC", "JNJ","WMB","HMC","MSFT", "TM"]
mse = main(tickers)
# Out:
# [*********************100%***********************]  1 of 1 completed
# (593, 200, 7)
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2024-12-01 15:34:12.934363: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0876
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0144
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0100
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0060
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0037
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0037
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0024
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0020
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0018
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0017
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0015
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0014
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0013
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0014
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0012
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3992e-04
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6577e-04
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5884e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.9724e-04
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4743e-04
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6078e-04
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.7236e-04
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.8524e-04
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.4146e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.7148e-04
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.4282e-04
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.5780e-04
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.2493e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2208e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.4096e-04
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6580e-04
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2563e-04
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.7195e-04
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2732e-04
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 7.1399e-04
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0315e-04
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0010
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8338e-04
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0010
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2147e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3738e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6186e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8874e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0962e-04
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0602e-04
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9413e-04
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4379e-04
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1062e-04
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2661e-04
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.3317e-04
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6581e-04
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8387e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4100e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2652e-04
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.6332e-04
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9504e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4391e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5957e-04
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0495e-04
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4032e-04
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2793e-04
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.5648e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0065e-04
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.1244e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7410e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8686e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6583e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5164e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4331e-04
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6602e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7269e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8316e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4616e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3906e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1884e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7783e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4069e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0824e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5917e-04
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7987e-04
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6520e-04
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4390e-04
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9638e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [11.824372898440561, 14.639160191683276, 13.361418694293382, 13.283878505620022, 9.541797219824462, 11.051628329793502, 13.330354551330016, 10.636459447382725, 15.050654498171577, 14.02847634115068, 7.537455553264623, 7.830278666607372, 6.082604221838698, 6.536819548187878, 12.777165760620257, 16.525674212273405, 15.2551167748336, 15.69949857600797, 13.421777356439842, 12.310597455569242, 11.927970471564405, 9.53743502927039, 11.063289897588849, 7.692850786197828, 11.331868701382541, 11.218908287815013, 7.381846641622325, 7.843123839121924, 9.17231021397654, 26.581934227850276]
# [*********************100%***********************]  1 of 1 completed
# (593, 200, 7)
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0450
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0082
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9487e-04
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1867e-04
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8027e-04
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4258e-04
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9529e-04
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2472e-04
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5562e-04
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0082e-04
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9276e-04
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4363e-04
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2829e-04
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1613e-04
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3221e-04
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6214e-04
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1145e-04
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2980e-04
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5954e-04
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5212e-04
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8840e-04
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9735e-04
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2594e-04
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0714e-04
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6736e-04
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0635e-04
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2977e-04
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1984e-04
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4929e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4357e-04
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4974e-04
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3563e-04
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3857e-04
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4035e-04
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1220e-04
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9941e-04
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5174e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8368e-04
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1076e-04
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0032e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0953e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4476e-04
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8633e-04
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1356e-04
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2756e-04
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3512e-04
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3977e-04
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9668e-04
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3137e-04
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6806e-04
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8871e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5399e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0068e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9921e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6936e-04
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7798e-04
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9567e-04
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0149e-04
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1667e-04
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3405e-04
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0156e-04
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9009e-04
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6319e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4712e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6547e-04
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5680e-04
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3118e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6009e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8347e-04
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0342e-04
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3905e-04
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4238e-04
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6498e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5317e-04
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5062e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2509e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6119e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9560e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8174e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7244e-04
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7913e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4478e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1641e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2435e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2504e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2712e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2528e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0304e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4253e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3543e-04
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4338e-04
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2785e-04
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7603e-04
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1234e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [0.5388065260051662, 0.5742312942913935, 0.5837481840004055, 0.5221928851275812, 0.5313913130434622, 0.5897420415126173, 0.5384176660078692, 0.5975132215157567, 0.5422529960442988, 0.5735344150856957, 0.7709588369119846, 0.7889911029406468, 0.45156317654334266, 1.2621231966014037, 0.7151857573579283, 0.7961573971779863, 0.7858358312627318, 0.7271400360685429, 0.818881749246029, 1.1299175465675109, 1.0864074729907442, 1.4155903271532737, 1.8674549839570505, 2.520708478158154, 1.8310708408753873, 2.865239189202339, 4.6998834230711095, 4.6833253242282655, 3.583863208192071, 15.76710015873949]
# [*********************100%***********************]  1 of 1 completed
# (593, 200, 7)
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1369
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0089
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0065
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0033
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0028
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0025
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9257e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.9827e-04
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7719e-04
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0919e-04
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1635e-04
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0957e-04
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0973e-04
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2537e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0899e-04
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0113e-04
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3009e-04
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7817e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6158e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3753e-04
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3117e-04
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8302e-04
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1114e-04
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3700e-04
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9825e-04
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2912e-04
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3179e-04
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6610e-04
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7933e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7827e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9250e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5470e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7385e-04
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6285e-04
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5464e-04
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6099e-04
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2265e-04
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4043e-04
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5787e-04
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6742e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2140e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3210e-04
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5408e-04
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2562e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9322e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5973e-04
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.3001e-04
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6958e-04
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9726e-04
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0439e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9517e-04
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3196e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2158e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1479e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2671e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7576e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3301e-04
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1658e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2672e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1663e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9849e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9698e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5700e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1052e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8312e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0421e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8078e-04
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7325e-04
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9406e-04
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0756e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [3.292438603084401, 2.338756485318467, 3.112909212920739, 2.6154875738894745, 2.563014288504045, 1.9228727997986734, 2.782812656408026, 1.5279692470343655, 1.5850361335087244, 1.8418518201873524, 1.7213516977966925, 1.3534911493433208, 1.641387333638416, 1.8351503040475128, 1.6582191493554117, 1.8461937949567215, 2.246456019658435, 2.1197801304324897, 1.900795003682657, 1.9559715500130737, 1.682905903541787, 2.6377970897182883, 2.6559773003594866, 2.9105368739624033, 2.079051870437934, 2.5416515127767543, 2.9539136219233497, 3.0660335766661317, 4.609440691594718, 16.962310306519154]
# [*********************100%***********************]  1 of 1 completed
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# (593, 200, 7)
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.1010
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0086
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9943e-04
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8751e-04
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2387e-04
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7230e-04
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9973e-04
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7788e-04
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6021e-04
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9489e-04
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5892e-04
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0665e-04
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6701e-04
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2569e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9003e-04
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2456e-04
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6197e-04
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1283e-04
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1312e-04
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1853e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9227e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4915e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0337e-04
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2269e-04
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4330e-04
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3008e-04
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2938e-04
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6587e-04
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5866e-04
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6685e-04
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4551e-04
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8844e-04
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4250e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6604e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3141e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4846e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0507e-04
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2990e-04
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1857e-04
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8060e-04
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0962e-04
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0211e-04
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9935e-04
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2773e-04
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1716e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8854e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2409e-04
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3235e-04
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1697e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9121e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8228e-04
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8079e-04
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8400e-04
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4764e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9205e-04
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2987e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3400e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8216e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7090e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8874e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4850e-04
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7669e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2694e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0749e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3201e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4432e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0854e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2533e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5275e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6905e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4021e-04
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1073e-04
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9912e-04
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8924e-04
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9054e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [3.2156375229080463, 3.5345867331596157, 3.496943453344482, 4.144414712034779, 3.5433786705544947, 3.33512014863095, 4.440687464817534, 3.467339990455833, 2.578981106531956, 2.7105545915065856, 2.708439467813012, 2.8755331054915, 3.659654609994337, 2.41216331180226, 3.633663828345694, 3.111612059950296, 2.5369949788181243, 2.282088380257457, 3.0553526766068826, 2.988766984502703, 2.44576322176149, 2.8240387238341116, 4.0368031902675545, 4.858341688554718, 4.224690683482368, 5.359669301655503, 6.550498655669124, 4.629775867000084, 3.986638667522358, 41.71704013200388]
# [*********************100%***********************]  1 of 1 completed
# (593, 200, 7)
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.1068
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0200
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0115
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0112
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0081
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0109
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8887e-04
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9819e-04
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0034e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8932e-04
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6835e-04
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5150e-04
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9885e-04
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8770e-04
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8382e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1608e-04
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6586e-04
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5690e-04
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6571e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8995e-04
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3402e-04
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4836e-04
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5068e-04
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1955e-04
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5388e-04
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3094e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5219e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0341e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5310e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6773e-04
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3567e-04
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4902e-04
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3868e-04
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9611e-04
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4733e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0666e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4286e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9903e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0811e-04
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5298e-04
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0423e-04
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9063e-04
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5912e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8306e-04
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7070e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6803e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9437e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0220e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1249e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4816e-04
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1084e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7316e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7526e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.4040e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1893e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2756e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3154e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1499e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6299e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4284e-04
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1783e-04
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2855e-04
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7850e-04
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3921e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [0.9312791620705334, 0.7676376117027449, 0.8024983955958889, 0.6029016632062174, 0.7142856753111841, 0.8301387270803594, 1.02408848654639, 0.8431657137480075, 0.7522584844308232, 0.8500498591007112, 0.7301655922654873, 0.808184674224552, 0.94089311948434, 0.9515085373450153, 0.6791579911090402, 0.8394451563093754, 0.8281232656838833, 0.6476599110061181, 0.6527972787884117, 0.6039021206670891, 0.5270883699764517, 0.38013312306598834, 0.5211064927134337, 0.5997771657170957, 0.6712684799033364, 0.4829545756402864, 0.42521604333932295, 0.4202995934554068, 0.4940425983689104, 7.644195833748238]
# [*********************100%***********************]  1 of 1 completed
# (593, 200, 7)
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1091
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0189
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0158
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0050
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023
# ...
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7293e-04
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4692e-04
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6488e-04
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5173e-04
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.5843e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7767e-04
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6005e-04
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5481e-04
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3988e-04
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.5907e-04
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8238e-04
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.5401e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0236e-04
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4588e-04
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5419e-04
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7201e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5719e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6541e-04
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9629e-04
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1478e-04
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7374e-04
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3487e-04
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1024e-04
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3247e-04
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2832e-04
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5160e-04
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6934e-04
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1441e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4909e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3583e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0295e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6747e-04
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2798e-04
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1533e-04
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8622e-04
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2128e-04
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1198e-04
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5607e-04
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3469e-04
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1711e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5683e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4470e-04
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4811e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5018e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1619e-04
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6045e-04
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1555e-04
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5071e-04
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5254e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8585e-04
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6699e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5194e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1516e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6051e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2323e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2959e-04
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7452e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3876e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3618e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5591e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6459e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5006e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3627e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7482e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8351e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9245e-04
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5088e-04
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3734e-04
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1054e-04
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9473e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [4.163742688841315, 3.5634370482130078, 2.7908933978578747, 3.7329056245170924, 3.955071725224384, 3.3966850355600697, 4.488368461768525, 4.002069038486853, 2.728356999843211, 3.412140116685791, 2.641156275527478, 2.7035758963799563, 3.877136375349108, 3.080836207344913, 3.91958895926693, 3.940996696921321, 2.8092349310037834, 3.5572350573163685, 2.8744068351904026, 3.9824191013809243, 2.86602848715762, 2.5125252277188803, 3.5898185360569745, 4.938396269878662, 4.342796648293169, 5.574217659170135, 5.900288980925902, 5.366221511792434, 4.121876449531561, 37.035338931554435]
# [*********************100%***********************]  1 of 1 completed
# (593, 200, 7)
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0737
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0066
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7292e-04
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8718e-04
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1074e-04
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.7752e-04
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8226e-04
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4066e-04
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5596e-04
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2104e-04
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4703e-04
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3105e-04
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2888e-04
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6074e-04
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5025e-04
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6287e-04
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3228e-04
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6590e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6722e-04
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0323e-04
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3052e-04
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3818e-04
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0389e-04
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9145e-04
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7166e-04
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2200e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3011e-04
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0967e-04
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9706e-04
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9480e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3288e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3545e-04
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3910e-04
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1523e-04
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9430e-04
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8848e-04
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1121e-04
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1192e-04
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3258e-04
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9481e-04
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5323e-04
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5227e-04
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2686e-04
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1828e-04
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7885e-04
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4023e-04
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3861e-04
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6955e-04
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6754e-04
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7816e-04
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5059e-04
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5994e-04
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3959e-04
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8239e-04
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3199e-04
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6622e-04
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4266e-04
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4957e-04
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6902e-04
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1333e-04
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9776e-04
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4530e-04
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8989e-04
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5789e-04
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3660e-04
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0902e-04
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5261e-04
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6849e-04
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6374e-04
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8746e-04
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1472e-04
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1312e-04
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6223e-04
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5717e-04
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2417e-04
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9201e-04
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8727e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.9760e-04
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5261e-04
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3279e-04
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4063e-04
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2161e-04
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8605e-04
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4336e-04
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2700e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [3.1796174406635673, 3.3346203542954576, 2.5254880408050195, 3.08321163481007, 2.2930583387428203, 1.697710683896459, 1.4253869170283124, 1.2638034009970156, 1.5435606810955835, 1.1291615011098928, 1.3670045632264596, 0.8683275364820159, 0.9816740948992496, 1.425899549618474, 1.687637478756747, 1.2650144679839672, 1.5766929581566116, 1.2822641426490096, 1.8477249612339322, 2.1512147914702093, 1.5830479973103329, 2.624230897001132, 2.879997064669039, 2.6731961992937516, 3.6509842181408514, 3.0485481757317805, 4.5307181222271105, 5.446683033218515, 5.055937423635938, 8.34443560347404]

# %%
mse
# Out:
# 16.14756794900699
