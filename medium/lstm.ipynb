# %%
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, LeakyReLU,LSTM
from tensorflow.keras.optimizers import Adam
from scipy.stats import norm
from scipy.linalg import svd
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import os 

# Fetch stock data from Yahoo Finance
def fetch_stock_data(ticker, start_date, end_date):
    data = yf.download(ticker, start=start_date, end=end_date)
    return data

# Compute technical indicators
def compute_technical_indicators(data):
    data['SMA30'] = data['Close'].rolling(window=3).mean()
    # data['SMA100'] = data['Close'].rolling(window=5).mean()
    vol_window = 3
    data['Volatility'] = data['Close'].pct_change().rolling(window=vol_window).std() * np.sqrt(252)
    return data.dropna()

# Black-Scholes option pricing model
def black_scholes(S, K, T, r, sigma, option_type='call'):
    d1 = (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    if option_type == 'call':
        return S * norm.cdf(d1) - K * np.exp(-r * T) * norm.cdf(d2)
    elif option_type == 'put':
        return K * np.exp(-r * T) * norm.cdf(-d2) - S * norm.cdf(-d1)

# Apply Black-Scholes model to generate option prices
def add_option_pricing_features(data):
    strike_price = data['Close'] * 1.05
    time_to_maturity = 30 / 252
    risk_free_rate = 0.01
    option_type = 'call'
    data['Option_Price'] = black_scholes(data['Close'], strike_price, time_to_maturity, risk_free_rate, data['Volatility'], option_type)
    data['Implied_Volatility'] = data['Volatility']
    return data

# Normalize and apply PCA for dimensionality reduction
def preprocess_data(data, n_pca_components=2):
    scaler = MinMaxScaler()
    data_scaled = scaler.fit_transform(data)
    # pca = PCA(n_components=n_pca_components)
    # data_pca = pca.fit_transform(data_scaled)
    # return np.hstack((data_scaled, data_pca))
    return data_scaled, scaler

# Create sequences for time-series prediction
def create_sequences(data, seq_len, pred_len):
    sequences = []
    for i in range(len(data) - seq_len - pred_len + 1):
        sequences.append(data[i:i + seq_len + pred_len])
    return np.array(sequences)

# Function to create a Hankel matrix
def create_hankel_matrix(time_series, window_size):
    # Create a Hankel matrix where the columns are shifted versions of the time series
    hankel_matrix = np.array([time_series[i:i + window_size] for i in range(len(time_series) - window_size + 1)])
    return hankel_matrix

# Function to perform SVD on the Hankel matrix
def hankel_svd(hankel_matrix):
    # Perform SVD on the Hankel matrix
    U, Sigma, Vt = svd(hankel_matrix, full_matrices=False)
    return U, Sigma, Vt

# Build a neural network model
def build_model(input_shape, output_len):
    model = Sequential([
        # LSTM(200, return_sequences=False, input_shape=input_shape),  # LSTM layer
        # LeakyReLU(),  # Apply Leaky ReLU to LSTM outputs
        LSTM(200, activation='relu', return_sequences=False),  # LSTM layer
        Dense(180),
        LeakyReLU(),
        Dense(360),
        LeakyReLU(),
        Dense(360),
        LeakyReLU(),
        Dense(output_len)  # Output layer
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    return model



def predict_and_plot(m, ticker, data, s, model, seq_len, pred_len, scaler, cut_off):
    plt.figure(figsize=(14, 7))

    rmse_values = []  # To store RMSE values for each section
    section_start_idx = []  # To store the start indices of each 30-day section for placement of RMSE labels
    #s.shape[0]
    pred_count = 0
    red_x,red_y, black_y, blue_x, blue_y, green_y = [],[],[],[],[],[]
    for idx in range(0,s.shape[0], pred_len):  # Loop through each 30-day block
    # for idx in range(1): # only first 30 after being trained
        # Input remains in 3D for predictio
        future_input = s[idx, :seq_len, :].reshape(1, seq_len, -1)  # Keep the 3D shape
        future = model.predict(future_input)[0]  # Predict future "Close" prices
        # Pad the prediction with zeros for the "Volume" and "SMA" columns
        future_padded = np.hstack((future.reshape(-1, 1), np.zeros((future.shape[0], data.shape[1] - 1))))  # Adjust for PCA features

        # Inverse transform the padded prediction
        future_transform = scaler.inverse_transform(future_padded)[:, 0]  # Extract "Close"

        # Extract and inverse transform the true "Close" values
        future_true = s[idx, seq_len:, 0].reshape(-1, 1)  # Use only "Close"
        future_true_padded = np.hstack((future_true, np.zeros((future_true.shape[0], data.shape[1] - 1))))  # Adjust for PCA features
        future_true_transform = scaler.inverse_transform(future_true_padded)[:, 0]  # Extract "Close"

        # Calculate RMSE for this 30-day section
        percent_error = np.mean(np.abs((future_true_transform - future_transform) / future_true_transform)) * 100
        rmse_values.append(percent_error)
        section_start_idx.append(idx)  # Store the start index for the percentage error label
        if idx< cut_off:
            red_x +=[idx]
            red_y+=[future_transform]
            black_y+=[future_true_transform]
        else:
            blue_x +=[idx]
            blue_y+=[future_transform]
            green_y+=[future_true_transform]

        # # Plot the predictions
        # plt.scatter(idx, future_transform, 
        # # label="Train Prediction" if idx < cut_off else "Test Prediction", 
        #     color="red" if idx < cut_off else "blue")


        # # plt.plot(np.arange(idx, idx + pred_len), future_transform, 
        # #         # label="Train Prediction" if idx < cut_off else "Test Prediction", 
        # #          color="red" if idx < cut_off else "blue")

        # # Plot the true values
        # plt.scatter(idx, future_true_transform, 
        #          #label="Train True" if idx < cut_off else "Test True", 
        #          color="black" if idx < cut_off else "green")

        
        if idx >= cut_off:
            pred_count+=1
    plt.plot(red_x, red_y, color = "red")
    plt.plot(red_x, black_y, color = "black")
    plt.plot(blue_x, blue_y, color = "blue")
    plt.plot(blue_x, green_y, color = "green")
    # Add legend and grid
    # plt.legend(["Train Prediction", "Train True", "Test Prediction", "Test True"])
    plt.plot([], [], color="red", label="Train Prediction")  # Dummy plot for legend
    plt.plot([], [], color="black", label="Train True")      # Dummy plot for legend
    plt.plot([], [], color="blue", label="Test Prediction")  # Dummy plot for legend
    plt.plot([], [], color="green", label="Test True")      # Dummy plot for legend
    plt.legend()
    # for idx in range(0, s.shape[0], pred_len): 
    # Add vertical line to separate each 30-day section
        # plt.axvline(x=idx + pred_len, color='gray', linestyle='--', linewidth=1)
    # Title and labels
    
    plt.title(f"{seq_len}-{pred_len} Predictions for {ticker}, model {m}")
    plt.xlabel("Trading Days")
    plt.ylabel("Price")

    # Add RMSE labels below the x-axis at the start of each 30-day section
    # for i, rmse in zip(section_start_idx, rmse_values):
    #     plt.text(i + pred_len / 2, min(plt.ylim()), f"{rmse:.0f}", color="teal", fontsize=10, ha='center', va='top')
    # plt.text(- 5- pred_len / 2, min(plt.ylim()), f"RMSE", color="teal", fontsize=10, ha='center', va='top')
    # print(rmse_values)
    # plt.grid(True)
    if m == "LSTM w/ 1 feature":
        dir = f"{seq_len}-{pred_len}/lstm_1"
        if not os.path.exists(dir):
                os.makedirs(dir)
        plt.savefig(f"{dir}/{ticker}.png")
    return rmse_values[-1] # testing rmse

    # plt.show()

# Call the function


# Main workflow
def main(tickers):
    m = "LSTM w/ 1 feature"
    test_rmse = []
    for ticker in tickers:
        # Step 1: Fetch data
        tsla = fetch_stock_data(ticker, start_date="2024-11-03", end_date="2024-12-02")

        # Step 2: Compute indicators
        tsla = compute_technical_indicators(tsla)

        # Step 3: Add Black-Scholes option pricing
        # tsla = add_option_pricing_features(tsla)

        # Step 4: Prepare data for training
        features = ['Close']#, 'Volume', 'SMA30', 'SMA100', 'Volatility']
        data = tsla[features].copy()
        # # Step 5: Perform Hankel Matrix Decomposition
        # window_size = 50  # Size of the sliding window to form the Hankel matrix
        # hankel_matrix = create_hankel_matrix(data['Close'].values, window_size)

        # # Step 6: Perform SVD on the Hankel matrix
        # U, Sigma, Vt = hankel_svd(hankel_matrix)

        # # You can choose the first few singular values and modes to add as features
        # num_modes = 2  # Number of modes to add as features
        # dmd_modes = U[:, :num_modes]  # Select the modes
        # dmd_amplitudes = Sigma[:num_modes]  # Select the amplitudes

        # # Step 7: Normalize and apply PCA for dimensionality reduction
        processed_data,scaler = preprocess_data(data)

        # # Trim the processed_data to match the number of rows in dmd_modes
        # processed_data_trimmed = processed_data[-dmd_modes.shape[0]:]  # Trim to match the length of dmd_modes

        # # Combine the Hankel decomposition modes with the processed data
        # data_combined = np.hstack((processed_data_trimmed, dmd_modes))

        # Step 8: Create sequences for time-series prediction
        seq_len = 1 # 6 months of data
        pred_len = 1  # Predict the next 20 days
        sequences = create_sequences(processed_data, seq_len, pred_len)

        # Step 9: Split data into training and testing
        cut_off = int(0.8 * sequences.shape[0])
        X_train = sequences[:cut_off, :seq_len, :]
        X_test = sequences[cut_off:, :seq_len, :]
        y_train = sequences[:cut_off, seq_len:, 0]
        y_test = sequences[cut_off:, seq_len:, 0]
        print(sequences.shape)
        
        # Step 10: Build and train the model
        model = build_model(input_shape=(seq_len, X_train.shape[2]), output_len=pred_len)
        history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=32,
            verbose=1
        )

        test_rmse += [predict_and_plot(m, ticker, processed_data, sequences, model, seq_len, pred_len, scaler, cut_off)]

    mse_for_model  = np.mean(test_rmse)
    return mse_for_model
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
tickers = ["TSLA", "NVDA","AMZN","MSFT", "BIPC", "JNJ","WMB","HMC","MSFT", "TM"] # 
mse = main(tickers)
# Out:
# [*********************100%***********************]  1 of 1 completed
# (15, 2, 1)
# Epoch 1/100
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator at 0x7f9665effd00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.5114
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.4451
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3748
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2947
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2072
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1213
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0564
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0451
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.1001
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.1326
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.1134
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0767
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0497
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0403
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0446
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0545
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0634
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0681
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0679
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0636
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0569
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0497
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0437
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0404
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0405
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0433
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0469
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0490
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0488
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0466
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0436
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0413
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0402
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0404
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0413
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0424
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0432
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0434
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0429
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0421
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0412
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0404
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0401
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0403
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0407
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0411
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0414
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0413
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0410
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0406
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0402
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0401
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0402
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0404
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0405
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0406
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0406
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0404
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0403
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0401
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0401
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0401
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0402
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0402
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0403
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0402
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0402
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0401
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0400
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0400
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0401
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0401
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0401
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0401
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0401
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0400
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0400
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0400
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0400
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0400
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0400
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0400
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0400
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0400
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0400
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0400
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0400
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0400
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0400
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0399
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0399
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0399
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0399
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0399
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0399
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0399
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0399
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0399
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0399
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0399
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [*********************100%***********************]  1 of 1 completed
# (15, 2, 1)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.5241
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 577ms/step - loss: 0.4502
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step - loss: 0.3764
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step - loss: 0.2932
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step - loss: 0.2034
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step - loss: 0.1181
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step - loss: 0.0624
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step - loss: 0.0745
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step - loss: 0.1360
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step - loss: 0.1477
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step - loss: 0.1154
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0789
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step - loss: 0.0596
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step - loss: 0.0589
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step - loss: 0.0686
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step - loss: 0.0797
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step - loss: 0.0867
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step - loss: 0.0879
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step - loss: 0.0841
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step - loss: 0.0770
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step - loss: 0.0691
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step - loss: 0.0623
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step - loss: 0.0584
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 779ms/step - loss: 0.0582
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 787ms/step - loss: 0.0610
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 910ms/step - loss: 0.0649
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 809ms/step - loss: 0.0676
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 733ms/step - loss: 0.0677
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 846ms/step - loss: 0.0654
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step - loss: 0.0621
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step - loss: 0.0594
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 873ms/step - loss: 0.0581
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 793ms/step - loss: 0.0583
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step - loss: 0.0594
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step - loss: 0.0607
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step - loss: 0.0616
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0618
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - loss: 0.0612
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0602
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0590
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0581
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0578
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0581
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0586
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0591
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0593
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0590
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0585
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0580
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0576
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0576
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0578
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0580
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0581
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0581
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0579
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0576
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0574
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0573
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0573
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0574
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0574
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0574
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0573
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0572
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0570
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0570
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0570
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0570
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0570
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0570
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0569
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0568
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0567
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0567
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0567
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0567
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0566
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0566
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0565
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0565
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0564
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0564
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0564
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0564
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0563
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0563
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0562
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0562
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0562
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0562
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0561
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0561
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0561
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0561
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0560
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0560
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0560
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0560
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0559
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 798ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# [*********************100%***********************]  1 of 1 completed
# (15, 2, 1)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.2892
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.2455
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.2001
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.1513
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.1028
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0654
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0578
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0867
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.1006
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0868
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0667
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0548
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0537
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0591
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0652
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0681
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0669
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.0625
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0568
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.0517
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0487
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0485
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - loss: 0.0503
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0521
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0520
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0495
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.0461
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.0435
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.0427
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.0435
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.0446
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.0447
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0434
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0416
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.0404
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0405
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0413
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0420
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0418
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0409
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0402
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 19s 19s/step - loss: 0.0403
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0407
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0409
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0407
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.0402
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0398
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - loss: 0.0398
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - loss: 0.0400
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.0401
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0401
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.0399
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0397
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - loss: 0.0396
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0397
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.0397
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.0397
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0396
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0394
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0394
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - loss: 0.0394
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - loss: 0.0394
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0394
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.0393
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0392
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0392
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0392
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.0392
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0391
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0391
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0390
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0390
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.0390
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.0390
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0390
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0389
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0389
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0388
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0388
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0388
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.0388
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0387
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.0387
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0387
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.0386
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0386
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0386
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0386
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0385
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0385
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0385
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0384
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0384
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0384
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0384
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0383
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.0383
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.0383
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.0383
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0382
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# [*********************100%***********************]  1 of 1 completed
# (15, 2, 1)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 35s 35s/step - loss: 0.2453
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - loss: 0.2135
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - loss: 0.1819
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - loss: 0.1464
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - loss: 0.1094
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 0.0771
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0618
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0769
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 0.0963
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0925
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0775
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - loss: 0.0654
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0614
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0638
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - loss: 0.0686
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0724
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0735
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0721
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0691
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0656
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0626
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 0.0610
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0610
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0623
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - loss: 0.0638
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0645
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0639
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0624
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - loss: 0.0607
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0596
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - loss: 0.0594
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0598
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0603
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0606
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0604
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0598
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0590
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0584
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0581
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 0.0582
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0585
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0587
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 0.0586
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0583
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0580
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - loss: 0.0578
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - loss: 0.0579
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - loss: 0.0581
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.0582
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0581
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 0.0579
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 0.0577
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0577
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0577
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0578
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0578
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0577
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0575
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0575
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0574
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0574
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0574
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0574
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0573
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0573
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0572
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0572
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0572
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0571
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0571
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - loss: 0.0570
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0569
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - loss: 0.0569
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0569
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0568
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - loss: 0.0568
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0567
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0567
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - loss: 0.0566
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0566
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 0.0565
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0564
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.0564
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - loss: 0.0563
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0563
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0562
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0561
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - loss: 0.0561
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - loss: 0.0560
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - loss: 0.0559
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0559
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - loss: 0.0558
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0557
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.0557
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0556
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0555
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0555
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0554
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 0.0553
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - loss: 0.0553
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 684ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# [*********************100%***********************]  1 of 1 completed
# (15, 2, 1)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 20s 20s/step - loss: 0.2265
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - loss: 0.1997
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 911ms/step - loss: 0.1726
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.1424
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.1105
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 880ms/step - loss: 0.0808
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - loss: 0.0619
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - loss: 0.0663
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - loss: 0.0863
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 657ms/step - loss: 0.0898
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - loss: 0.0784
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step - loss: 0.0655
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - loss: 0.0584
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 0.0578
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - loss: 0.0608
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.0643
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0662
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0657
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0632
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0595
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0557
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0528
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - loss: 0.0516
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0521
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - loss: 0.0534
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0540
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0530
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0508
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0485
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - loss: 0.0471
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - loss: 0.0470
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - loss: 0.0477
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 0.0484
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0483
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0474
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0463
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - loss: 0.0457
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0459
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0464
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0466
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0461
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - loss: 0.0453
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - loss: 0.0448
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.0448
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - loss: 0.0450
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - loss: 0.0450
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0448
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0444
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0441
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0441
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - loss: 0.0442
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0443
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0441
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0438
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0436
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0436
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0436
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0435
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0433
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0432
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0431
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 0.0431
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0429
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0428
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 0.0427
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0425
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0425
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0424
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0422
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0421
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0420
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0419
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0417
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0416
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0415
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0414
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0412
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 0.0411
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - loss: 0.0410
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0408
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0407
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 0.0406
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 0.0405
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - loss: 0.0403
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.0402
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.0401
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.0400
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0398
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - loss: 0.0397
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.0396
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 0.0395
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0394
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0392
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0392
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0390
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.0390
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - loss: 0.0389
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0388
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0387
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - loss: 0.0386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# [*********************100%***********************]  1 of 1 completed
# (15, 2, 1)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.2827
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.2453
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.2058
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.1616
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.1155
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0754
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0562
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0752
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0999
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0958
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0776
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0623
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0565
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0583
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0635
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0682
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0706
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0703
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0679
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0644
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0607
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0579
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0566
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0571
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0588
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0605
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0613
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0607
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0592
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0576
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0565
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0562
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0564
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0570
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 35s 35s/step - loss: 0.0575
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - loss: 0.0576
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0574
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0569
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0563
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0557
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0554
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0554
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0556
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.0558
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0558
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0556
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0553
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0550
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0548
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0547
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0548
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0549
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0549
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0548
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0546
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0545
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0543
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0543
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0544
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0544
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0544
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0543
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0542
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0542
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0541
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0542
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0542
# Epoch 68/100

# %%
mse
# Out:
# 13.33110879740637
